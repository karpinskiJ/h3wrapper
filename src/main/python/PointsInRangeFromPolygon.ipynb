# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .config("spark.executor.memory", "1g")\
        .config("spark.driver.memory", "4g")\
.appName('VIZ') \
 .master("local[*]")\
    .getOrCreate()
from utils import *
from sedona.spark import *
from pyspark.sql.functions import *
SedonaContext.create(spark)
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://KubaKarpLegion.home:4055">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>VIZ</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
points = spark.read.parquet("data/POINT_IN_RANGE_FROM_POLYGON_ZIPCODES").drop("meter_zc_shape").where(col("zc_id") =="36522"). toPandas()

# %%
points.show()
# Out:
# +-----+--------------------+--------------------+--------------------+
# |zc_id|            zc_shape|        zc_shape_wkt|      meter_zc_shape|
# +-----+--------------------+--------------------+--------------------+
# |36522|POLYGON ((-88.536...|POLYGON ((-88.432...|POLYGON ((1097634...|
# |36525|POLYGON ((-88.188...|POLYGON ((-88.088...|POLYGON ((1134082...|
# |36512|POLYGON ((-87.962...|POLYGON ((-88.037...|POLYGON ((1152383...|
# |35592|POLYGON ((-88.354...|POLYGON ((-88.247...|POLYGON ((1081373...|
# |36693|POLYGON ((-88.294...|POLYGON ((-88.190...|POLYGON ((1126791...|
# |36695|POLYGON ((-88.334...|MULTIPOLYGON (((-...|POLYGON ((1124780...|
# |36521|POLYGON ((-88.436...|POLYGON ((-88.335...|POLYGON ((1108324...|
# |36523|POLYGON ((-88.375...|POLYGON ((-88.271...|POLYGON ((1122242...|
# |36575|POLYGON ((-88.442...|POLYGON ((-88.340...|POLYGON ((1111359...|
# |36619|POLYGON ((-88.361...|POLYGON ((-88.258...|POLYGON ((1120703...|
# |36541|POLYGON ((-88.506...|POLYGON ((-88.406...|POLYGON ((1107680...|
# |36571|POLYGON ((-88.270...|POLYGON ((-88.166...|POLYGON ((1126496...|
# |36544|POLYGON ((-88.395...|POLYGON ((-88.293...|POLYGON ((1119550...|
# |36572|POLYGON ((-88.193...|POLYGON ((-88.089...|POLYGON ((1133364...|
# +-----+--------------------+--------------------+--------------------+

# %%
m = folium.Map(location=[ 31.160, -88.452]) 
add_polygon_to_map(points,m,"zc_shape",color="blue",opacity=0.001, line_weight=3)
add_polygon_to_map(points,m,"zc_shape_wkt",color="red",opacity=0.1, line_weight=2)
# add_circle_to_map(points,m,"lat","long",color="blue")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15896de38c1edfcfbf954df11389592e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15896de38c1edfcfbf954df11389592e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15896de38c1edfcfbf954df11389592e = L.map(
#                 &quot;map_15896de38c1edfcfbf954df11389592e&quot;,
#                 {
#                     center: [31.16, -88.452],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16a0e37ca6451eb53ecbfe3d2d45e341 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15896de38c1edfcfbf954df11389592e);
#
#
#         function geo_json_9c61031beff75366716790ad533e79e6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.001, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_9c61031beff75366716790ad533e79e6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9c61031beff75366716790ad533e79e6 = L.geoJson(null, {
#                 onEachFeature: geo_json_9c61031beff75366716790ad533e79e6_onEachFeature,
#
#                 style: geo_json_9c61031beff75366716790ad533e79e6_styler,
#         });
#
#         function geo_json_9c61031beff75366716790ad533e79e6_add (data) {
#             geo_json_9c61031beff75366716790ad533e79e6
#                 .addData(data)
#                 .addTo(map_15896de38c1edfcfbf954df11389592e);
#         }
#             geo_json_9c61031beff75366716790ad533e79e6_add({&quot;bbox&quot;: [-88.53620030065507, 30.770616237767104, -87.99602261470221, 31.318675591007267], &quot;features&quot;: [{&quot;bbox&quot;: [-88.53620030065507, 30.770616237767104, -87.99602261470221, 31.318675591007267], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[
quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed1c3ac72270e5976bd0c972e42f4102 = L.map(
#                 &quot;map_ed1c3ac72270e5976bd0c972e42f4102&quot;,
#                 {
#                     center: [31.16, -88.452],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0751ce81c7f74174076d8fedb484467d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed1c3ac72270e5976bd0c972e42f4102);
#
#
#         function geo_json_172b4b4046bfd44dc930ecd528763926_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.001, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_172b4b4046bfd44dc930ecd528763926_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_172b4b4046bfd44dc930ecd528763926 = L.geoJson(null, {
#                 onEachFeature: geo_json_172b4b4046bfd44dc930ecd528763926_onEachFeature,
#
#                 style: geo_json_172b4b4046bfd44dc930ecd528763926_styler,
#         });
#
#         function geo_json_172b4b4046bfd44dc930ecd528763926_add (data) {
#             geo_json_172b4b4046bfd44dc930ecd528763926
#                 .addData(data)
#                 .addTo(map_ed1c3ac72270e5976bd0c972e42f4102);
#         }
#             geo_json_172b4b4046bfd44dc930ecd528763926_add({&quot;bbox&quot;: [-88.55623876095248, 31.068765902254476, -88.34821909811885, 31.249848198231067], &quot;features&quot;: [{&quot;bbox&quot;: [-88.55623876095248, 31.068765902254476, -88.34821909811885, 31.249848198231067], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-88.34860698278443, 31.147109211136527], [-88.35297529350366, 31.129809305173673], [-88.3611540357673, 31.113644153160056], [-88.37282739485411, 31.099234083407463], [-88.38754610054316, 31.087131788765245], [-88.40474479251097, 31.077801250843315], [-88.42376370440203, 31.071600076809897], [-88.44387384009423, 31.068765902254476], [-88.46430470180984, 31.069407360720113], [-88.48427354784539, 31.073499951646948], [-88.50301510860464, 31.08088695912158], [-88.51981067381169, 31.091285389564092], [-88.53401548160608, 31.104296712933746], [-88.54508339191028, 31.1194220148686], [-88.55258791198918, 31.13608100209469], [-88.55623876095248, 31.15363415611368], [-88.55589331067054, 31.171407206128126], [-88.55156242049863, 31.18871699658049], [-88.5434103880294, 31.204897762180217], [-88.53174896165243, 31.219326797600576], [-88.51702559490833, 31.23144852264799], [-88.4998063576844, 31.24079599760708], [-88.48075414414254, 31.24700903678903], [-88.46060302028695, 31.249848198231067], [-88.44012972400508, 31.249204089175056], [-88.42012345731801, 31.245101613711633], [-88.40135518679956, 31.23769899259551], [-88.38454768903672, 31.227281596453984], [-88.37034754247999, 31.214250842690326], [-88.3593001775361, 31.19910860376537], [-88.35182895907278, 31.18243775144613], [-88.34821909811885, 31.164879610571795], [-88.34860698278443, 31.147109211136527]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_a85882757b91869283e7d64cfa31788e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.001, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_a85882757b91869283e7d64cfa31788e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a85882757b91869283e7d64cfa31788e = L.geoJson(null, {
#                 onEachFeature: geo_json_a85882757b91869283e7d64cfa31788e_onEachFeature,
#
#                 style: geo_json_a85882757b91869283e7d64cfa31788e_styler,
#         });
#
#         function geo_json_a85882757b91869283e7d64cfa31788e_add (data) {
#             geo_json_a85882757b91869283e7d64cfa31788e
#                 .addData(data)
#                 .addTo(map_ed1c3ac72270e5976bd0c972e42f4102);
#         }
#             geo_json_a85882757b91869283e7d64cfa31788e_add({&quot;bbox&quot;: [-88.55623876095248, 31.068765902254476, -88.34821909811885, 31.249848198231067], &quot;features&quot;: [{&quot;bbox&quot;: [-88.55623876095248, 31.068765902254476, -88.34821909811885, 31.24984819
