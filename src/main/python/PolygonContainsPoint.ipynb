# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .config("spark.executor.memory", "1g")\
        .config("spark.driver.memory", "4g")\
.appName('VIZ') \
 .master("local[*]")\
    .getOrCreate()

# %%
from utils import *
from sedona.spark import *
from pyspark.sql.functions import *
SedonaContext.create(spark)
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://KubaKarpLegion.home:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>VIZ</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
basic_polygon_transformed_to_h3 = spark.read.parquet("./data/POLYGON_CONTAINS_POINT/BASIC_H3_TRANSFORMATION").drop("bg_shape")
polygon_transformed_to_h3_full_cover = spark.read.parquet("./data/POLYGON_CONTAINS_POINT/H3_TRANSFORMATION_FULL_COVER").drop("bg_shape")
points_in_block_groups = spark.read.parquet("./data/POLYGON_CONTAINS_POINT/POINTS_IN_BLOCK_GROUPS").drop("bg_shape","point")
points_transformed_to_h3 = spark.read.parquet("./data/POLYGON_CONTAINS_POINT/POINTS_TRANSFORMED_H3").drop("point")

# %%
points_transformed_to_h3_2 = points_transformed_to_h3.join(points_in_block_groups.where(col("bg_id")=="010970064121"),["point_id"]).toPandas()

# %%
points_in_block_groups_2 = points_in_block_groups.where(col("bg_id")=="010970064121").toPandas()

# %%
m = folium.Map(location=[30.988, -88.325]) 
add_polygon_to_map(points_in_block_groups_2,m,"bg_shape_wkt",color="blue",opacity=0.01, line_weight=2.5)
add_circle_to_map(points_in_block_groups_2,m,"lat","long",color="red")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dd8d74915f958a5f31c7becc5630a16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dd8d74915f958a5f31c7becc5630a16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dd8d74915f958a5f31c7becc5630a16 = L.map(
#                 &quot;map_9dd8d74915f958a5f31c7becc5630a16&quot;,
#                 {
#                     center: [30.988, -88.325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e606c31d7558d025b4fc063cebefaa64 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dd8d74915f958a5f31c7becc5630a16);
#
#
#         function geo_json_1b2aa84111aa518197ca19416fca8d52_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.01, &quot;weight&quot;: 2.5};
#             }
#         }
#
#         function geo_json_1b2aa84111aa518197ca19416fca8d52_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1b2aa84111aa518197ca19416fca8d52 = L.geoJson(null, {
#                 onEachFeature: geo_json_1b2aa84111aa518197ca19416fca8d52_onEachFeature,
#
#                 style: geo_json_1b2aa84111aa518197ca19416fca8d52_styler,
#         });
#
#         function geo_json_1b2aa84111aa518197ca19416fca8d52_add (data) {
#             geo_json_1b2aa84111aa518197ca19416fca8d52
#                 .addData(data)
#                 .addTo(map_9dd8d74915f958a5f31c7becc5630a16);
#         }
#             geo_json_1b2aa84111aa518197ca19416fca8d52_add({&quot;bbox&quot;: [-88.27577699999999, 30.625363, -88.247948, 30.646672], &quot;features&quot;: [{&quot;bbox&quot;: [-88.27577699999999, 30.625363, -88.247948, 30.646672], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-88.27577699999999, 30.638647], [-88.27149, 30.640848], [-88.26643399999999, 30.644737], [-88.265382, 30.645031999999997], [-88.26129, 30.645227], [-88.258353, 30.646672], [-88.258383, 30.639931999999998], [-88.247948, 30.639991], [-88.2487, 30.637542999999997], [-88.251915, 30.62878], [-88.252687, 30.625363], [-88.262109, 30.625421], [-88.26208799999999, 30.626666999999998], [-88.263241, 30.626668], [-88.263353, 30.628096], [-88.26390699999999, 30.629123999999997], [-88.265712, 30.630777], [-88.266111, 30.630853], [-88.266065, 30.631619999999998], [-88.265095, 30.632510999999997], [-88.265231, 30.633395999999998], [-88.26503799999999, 30.633481], [-88.265345, 30.634728], [-88.265783, 30.634975999999998], [-88.266763, 30.634938], [-88.267195, 30.635351], [-88.267354, 30.636000000000003], [-88.267685, 30.636159], [-88.269071, 30.636225999999997], [-88.269714, 30.636495], [-88.270133, 30.636412999999997], [-88.271895, 30.636744], [-88.27261399999999, 30.6367], [-88.272849, 30.636913999999997], [-88.273504, 30.637024999999998], [-88.274503, 30.637641], [-88.274776, 30.638113999999998], [-88.27577699999999, 30.638647]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_1eb9b3402ec191fb54039527b61eb115_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.01, &quot;weight&quot;: 2.5};
#             }
#         }
#
#         function geo_json_1eb9b3402ec191fb54039527b61eb115_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1eb9b3402ec191fb54039527b61eb115 = L.geoJson(null, {
#                 onEachFeature: geo_json_1eb9b3402ec191fb54039527b61eb115_onEachFeature,
#
#                 style: geo_json_1eb9b3402ec191fb54039527b61eb115_styler,
#         });
#
#         function geo_json_1eb9b3402ec191fb54039527b61eb115_add (data) {
#             geo_json_1eb9b3402ec191fb54039527b61eb115
#                 .addData(data)
#                 .addTo(map_9dd8d74915f958a5f31c7becc5630a16);
#         }
#             geo_json_1eb9b3402ec191fb54039527b61eb115_add({&quot;bbox&quot;: [-88.27577699999999, 30.625363, -88.247948, 30.646672], &quot;features&quot;: [{&quot;bbox&quot;: [-88.27577699999999, 30.625363, -88.247948, 30.646672], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-88.27577699999999, 30.638647], [-88.27149, 30.640848], [-88.26643399999999, 30.644737], [-88.265382, 30.645031999999997], [-88.26129, 30.645227], [-88.258353, 30.646672], [-88.258383, 30.639931999999998], [-88.247948, 30.639991], [-88.2487, 30.637542999999997], [-88.251915,

# %%
full_cover_example_shape = polygon_transformed_to_h3_full_cover.where(col("bg_id")=="010730047012").toPandas()
full_cover_example_shape_2 = polygon_transformed_to_h3_full_cover.where(col("bg_id")=="010970064121").toPandas()

# %%
m = folium.Map(location=[30.988, -88.325]) 
add_polygon_to_map(full_cover_example_shape_2,m,"bg_shape_wkt",color="blue",opacity=0.1, line_weight=2.5)
add_polygon_to_map(full_cover_example_shape_2,m,"h3_index_shape",color="red",opacity=0.5, line_weight=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24f70a4f0eb00e925ba3fd5e30405771 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24f70a4f0eb00e925ba3fd5e30405771&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24f70a4f0eb00e925ba3fd5e30405771 = L.map(
#                 &quot;map_24f70a4f0eb00e925ba3fd5e30405771&quot;,
#                 {
#                     center: [30.988, -88.325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d16c470f87b94b75f9a812dfdf2e0d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24f70a4f0eb00e925ba3fd5e30405771);
#
#
#         function geo_json_811683e42f7ea1725eeff6eff219a47f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2.5};
#             }
#         }
#
#         function geo_json_811683e42f7ea1725eeff6eff219a47f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_811683e42f7ea1725eeff6eff219a47f = L.geoJson(null, {
#                 onEachFeature: geo_json_811683e42f7ea1725eeff6eff219a47f_onEachFeature,
#
#                 style: geo_json_811683e42f7ea1725eeff6eff219a47f_styler,
#         });
#
#         function geo_json_811683e42f7ea1725eeff6eff219a47f_add (data) {
#             geo_json_811683e42f7ea1725eeff6eff219a47f
#                 .addData(data)
#                 .addTo(map_24f70a4f0eb00e925ba3fd5e30405771);
#         }
#             geo_json_811683e42f7ea1725eeff6eff219a47f_add({&quot;bbox&quot;: [-88.27577699999999, 30.625363, -88.247948, 30.646672], &quot;features&quot;: [{&quot;bbox&quot;: [-88.27577699999999, 30.625363, -88.247948, 30.646672], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[
= L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_a0f1d4cfd56cd91c0cbd09e2ca1eae30 = L.circleMarker(
#                 [30.641769999999998, -88.26745699999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_51b8e022154676a2bd889e92a1ae719f = L.circleMarker(
#                 [30.639353999999997, -88.267307],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_3f7d079f8624b384f80bc01758cb12d7 = L.circleMarker(
#                 [30.642094, -88.26616299999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_720b108311f2486397db5abcb072d15b = L.circleMarker(
#                 [30.642785999999997, -88.26743999999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_970d5a17f8c9097ede7519d1384ef1ef = L.circleMarker(
#                 [30.63267899999999, -88.26326699999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_e9511f9616f2740d94c9d6df9c6ccd78 = L.circleMarker(
#                 [30.630876999999998, -88.263261],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_867843f75ab2720a62b58f419ab2871c);
#
#
#             var circle_marker_4c3c0

# %%
m = folium.Map(location=[33.511, -86.784]) 
add_polygon_to_map(full_cover_example_shape,m,"bg_shape_wkt",color="blue",opacity=0.1, line_weight=2.5)
add_polygon_to_map(full_cover_example_shape,m,"h3_index_shape",color="red",opacity=0.5, line_weight=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78cad3192ca5f756fb6a88959134e654 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78cad3192ca5f756fb6a88959134e654&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78cad3192ca5f756fb6a88959134e654 = L.map(
#                 &quot;map_78cad3192ca5f756fb6a88959134e654&quot;,
#                 {
#                     center: [33.511, -86.784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2651ceb91fedf051967ed59ee2faf945 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_78cad3192ca5f756fb6a88959134e654);
#
#
#         function geo_json_54f6e550a49608384205f185b01361e2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2.5};
#             }
#         }
#
#         function geo_json_54f6e550a49608384205f185b01361e2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_54f6e550a49608384205f185b01361e2 = L.geoJson(null, {
#                 onEachFeature: geo_json_54f6e550a49608384205f185b01361e2_onEachFeature,
#
#                 style: geo_json_54f6e550a49608384205f185b01361e2_styler,
#         });
#
#         function geo_json_54f6e550a49608384205f185b01361e2_add (data) {
#             geo_json_54f6e550a49608384205f185b01361e2
#                 .addData(data)
#                 .addTo(map_78cad3192ca5f756fb6a88959134e654);
#         }
#             geo_json_54f6e550a49608384205f185b01361e2_add({&quot;bbox&quot;: [-86.78478299999999, 33.503321, -86.776612, 33.512676], &quot;features&quot;: [{&quot;bbox&quot;: [-86.78478299999999, 33.503321, -86.776612, 33.512676], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-86.78478299999999, 33.51157], [-86.782668, 33.512552], [-86.782293, 33.512116], [-86.78206, 33.512256], [-86.780948, 33.512333999999996], [-86.78025799999999, 33.512676], [-86.78015099999999, 33.512446], [-86.779758, 33.512463], [-86.778386, 33.511279], [-86.778095, 33.510242], [-86.77808399999999, 33.508375], [-86.776775, 33.506414], [-86.776612, 33.504559], [-86.77717, 33.504551], [-86.777163, 33.503321], [-86.77850000000001, 33.503509], [-86.778566, 33.505133], [-86.779169, 33.505919999999996], [-86.779319, 33.505970999999995], [-86.77977399999999, 33.505682], [-86.780265, 33.505843999999996], [-86.78478299999999, 33.51157]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_3d270442da4ce645436f297c5ce61f0f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2.5};
#             }
#         }
#
#         function geo_json_3d270442da4ce645436f297c5ce61f0f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3d270442da4ce645436f297c5ce61f0f = L.geoJson(null, {
#                 onEachFeature: geo_json_3d270442da4ce645436f297c5ce61f0f_onEachFeature,
#
#                 style: geo_json_3d270442da4ce645436f297c5ce61f0f_styler,
#         });
#
#         function geo_json_3d270442da4ce645436f297c5ce61f0f_add (data) {
#             geo_json_3d270442da4ce645436f297c5ce61f0f
#                 .addData(data)
#                 .addTo(map_78cad3192ca5f756fb6a88959134e654);
#         }
#             geo_json_3d270442da4ce645436f297c5ce61f0f_add({&quot;bbox&quot;: [-86.78478299999999, 33.503321, -86.776612, 33.512676], &quot;features&quot;: [{&quot;bbox&quot;: [-86.78478299999999, 33.503321, -86.776612, 33.512676], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-86.78478299999999, 33.51157], [-86.782668, 33.512552], [-86.782293, 33.512116], [-86.78206, 33.512256], [-86.780948, 33.512333999999996], [-86.78025799999999, 33.512676], [-86.78015099999999, 33.512446], [-86.779758, 33.512463], [-86.778386, 33.511279], [-86.778095, 33.510242], [-86.77808399999999, 33.508375], [-86.776775, 33.506414], [-86.776612, 33.504559], [-86.77717, 33.504551], [-86.777163, 33.503321], [-86.77850000000001, 33.503509], [-86.778566, 33.505133], [-86.779169, 33.505919999999996], [-86.779319, 33.505970999999995], [-86.77977399999999, 33.505682], [-86.780265, 33.505843999999996], [-86.78478299999999, 33.51157]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot

# %%
example_shape = basic_polygon_transformed_to_h3.where(col("bg_id")=="010730047012").toPandas()

# %%
example_shape_2 = basic_polygon_transformed_to_h3.where(col("bg_id")=="010970059003").toPandas()

# %%
example_shape_2.iloc[1]
# Out:
# bg_id                                                  010970059003
# bg_shape_wkt      POLYGON ((-88.32589399999999 30.988571, -88.32...
# h3_index                                         609187747814440959
# h3_index_shape    POLYGON((-88.14971444742754 30.97224367050589,...
# Name: 1, dtype: object

# %%
m = folium.Map(location=[30.988, -88.325]) 
add_polygon_to_map(example_shape_2,m,"bg_shape_wkt",color="blue",opacity=0.1, line_weight=2.5)
add_polygon_to_map(example_shape_2,m,"h3_index_shape",color="red",opacity=0.5, line_weight=1)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23dbead08511e5dd5676bb7bae9140f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23dbead08511e5dd5676bb7bae9140f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23dbead08511e5dd5676bb7bae9140f9 = L.map(
#                 &quot;map_23dbead08511e5dd5676bb7bae9140f9&quot;,
#                 {
#                     center: [30.988, -88.325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8dfe9830b1457f073ec70a8d3741af2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_23dbead08511e5dd5676bb7bae9140f9);
#
#
#         function geo_json_14908999090d2389580f14d9fd9121c2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2.5};
#             }
#         }
#
#         function geo_json_14908999090d2389580f14d9fd9121c2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_14908999090d2389580f14d9fd9121c2 = L.geoJson(null, {
#                 onEachFeature: geo_json_14908999090d2389580f14d9fd9121c2_onEachFeature,
#
#                 style: geo_json_14908999090d2389580f14d9fd9121c2_styler,
#         });
#
#         function geo_json_14908999090d2389580f14d9fd9121c2_add (data) {
#             geo_json_14908999090d2389580f14d9fd9121c2
#                 .addData(data)
#                 .addTo(map_23dbead08511e5dd5676bb7bae9140f9);
#         }
#             geo_json_14908999090d2389580f14d9fd9121c2_add({&quot;bbox&quot;: [-88.32589399999999, 30.9145, -88.115893, 31.040746], &quot;features&quot;: [{&quot;bbox&quot;: [-88.32589399999999, 30.9145, -88.115893, 31.040746], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbfc01d92cf3d7dd74424fb3cd02944c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbfc01d92cf3d7dd74424fb3cd02944c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbfc01d92cf3d7dd74424fb3cd02944c = L.map(
#                 &quot;map_fbfc01d92cf3d7dd74424fb3cd02944c&quot;,
#                 {
#                     center: [33.511, -86.784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef9cffbff7b33ba6092ef17884e82693 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fbfc01d92cf3d7dd74424fb3cd02944c);
#
#
#         function geo_json_e573364f84c811a9d4d0c40428561f33_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_e573364f84c811a9d4d0c40428561f33_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e573364f84c811a9d4d0c40428561f33 = L.geoJson(null, {
#                 onEachFeature: geo_json_e573364f84c811a9d4d0c40428561f33_onEachFeature,
#
#                 style: geo_json_e573364f84c811a9d4d0c40428561f33_styler,
#         });
#
#         function geo_json_e573364f84c811a9d4d0c40428561f33_add (data) {
#             geo_json_e573364f84c811a9d4d0c40428561f33
#                 .addData(data)
#                 .addTo(map_fbfc01d92cf3d7dd74424fb3cd02944c);
#         }
#             geo_json_e573364f84c811a9d4d0c40428561f33_add({&quot;bbox&quot;: [-86.78478299999999, 33.503321, -86.776612, 33.512676], &quot;features&quot;: [{&quot;bbox&quot;: [-86.78478299999999, 33.503321, -86.776612, 33.512676], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-86.78478299999999, 33.51157], [-86.782668, 33.512552], [-86.782293, 33.512116], [-86.78206, 33.512256], [-86.780948, 33.512333999999996], [-86.78025799999999, 33.512676], [-86.78015099999999, 33.512446], [-86.779758, 33.512463], [-86.778386, 33.511279], [-86.778095, 33.510242], [-86.77808399999999, 33.508375], [-86.776775, 33.506414], [-86.776612, 33.504559], [-86.77717, 33.504551], [-86.777163, 33.503321], [-86.77850000000001, 33.503509], [-86.778566, 33.505133], [-86.779169, 33.505919999999996], [-86.779319, 33.505970999999995], [-86.77977399999999, 33.505682], [-86.780265, 33.505843999999996], [-86.78478299999999, 33.51157]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_3289c385d8520b0679efad06a36d0630_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_3289c385d8520b0679efad06a36d0630_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3289c385d8520b0679efad06a36d0630 = L.geoJson(null, {
#                 onEachFeature: geo_json_3289c385d8520b0679efad06a36d0630_onEachFeature,
#
#                 style: geo_json_3289c385d8520b0679efad06a36d0630_styler,
#         });
#
#         function geo_json_3289c385d8520b0679efad06a36d0630_add (data) {
#             geo_json_3289c385d8520b0679efad06a36d0630
#                 .addData(data)
#                 .addTo(map_fbfc01d92cf3d7dd74424fb3cd02944c);
#         }
#             geo_json_3289c385d8520b0679efad06a36d0630_add({&quot;bbox&quot;: [-86.79970375473185, 33.492198866530494, -86.77095746909694, 33.51716907428468], &quot;features&quot;: [{&quot;bbox&quot;: [-86.79970375473185, 33.492198866530494, -86.77095746909694, 33.51716907428468], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-86.78091608268134, 33.492198866530494], [-86.77095746909694, 33.50132935459041], [-86.77536924663862, 33.51381400520256], [-86.78974333183724, 33.51716907428468], [-86.79970375473185, 33.50803767028363], [-86.79528828337408, 33.49555211330488], [-86.78091608268134, 33.492198866530494]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
